# %% [markdown]
# # Final Project - ITM 454 FAQ Chatbot for AUPP Website

# %% [markdown]
# # 1. Load and Preview Chatbot Dataset

# %%
import pandas as pd
import json

file_path = 'dataset.json'

with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

df = pd.DataFrame(data)

df
# Out:
#                         category  \
# 0              Academic Policies
# 1              Academic Policies
# 2              Academic Policies
# 3              Academic Policies
# 4              Academic Policies
# ..                           ...
# 465  Tuition Fees & Scholarships
# 466  Tuition Fees & Scholarships
# 467  Tuition Fees & Scholarships
# 468  Tuition Fees & Scholarships
# 469  Tuition Fees & Scholarships
#
#                                               question  \
# 0        When can I take a leave of absence from AUPP?
# 1                     Who approves a leave of absence?
# 2            Where do I get the Leave of Absence form?
# 3    How long can I be on leave before I lose my st...
# 4    Can I return after taking a leave of absence, ...
# ..                                                 ...
# 465            What is the TOEFL ITP exam fee at AUPP?
# 466                    What is the placement exam fee?
# 467          Where can students pay tuition on campus?
# 468           Can students pay tuition using ABA Bank?
# 469               Can students pay using Canadia Bank?
#
#                                                 answer  \
# 0    You can request a Leave of Absence (LOA) for l...
# 1    The authority to grant a Leave of Absence rest...
# 2    You can obtain the LOA Form from the Office of...
# 3    The specific duration of leave allowed is deta...
# 4    Yes, you can return after taking a leave of ab...
# ..                                                 ...
# 465                  The TOEFL ITP exam fee is USD 30.
# 466                   The placement exam costs USD 30.
# 467  Students can pay tuition directly at the AUPP ...
# 468  Yes. Tuition can be paid via ABA mobile app or...
# 469  Yes. Payments can be made through the Canadia ...
#
#                                          alt_questions
# 0    [How do I apply for a leave of absence?, Can I...
# 1    [Who decides if I can take a leave?, Which off...
# 2    [How can I get the LOA form?, Where do I pick ...
# 3    [What is the maximum time I can be on leave?, ...
# 4    [How do I come back after a LOA?, Can I rejoin...
# ..                                                 ...
# 465  [How much is the TOEFL ITP exam fee?, Does AUP...
# 466  [How much is the placement exam fee?, Does AUP...
# 467  [Where is tuition paid at AUPP?, Can tuition b...
# 468  [Can tuition be paid through ABA Bank?, Does A...
# 469  [Can tuition be paid through Canadia Bank?, Do...
#
# [470 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category       470 non-null    object
#  1   question       470 non-null    object
#  2   answer         470 non-null    object
#  3   alt_questions  470 non-null    object
# dtypes: object(4)
# memory usage: 14.8+ KB

# %%
df["category"].value_counts()
# Out:
# category
# Academic Policies              144
# University Leadership           79
# Career/Faculty Info             69
# Programs & Majors               54
# Professional Programs           44
# Tuition Fees & Scholarships     41
# University Info                 39
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='category')
plt.title("Category Distribution")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 2. Text Preprocessing and Cleaning Function

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Download necessary NLTK data
nltk.download("punkt")
nltk.download('punkt_tab')
nltk.download("stopwords")
nltk.download("wordnet")

# Initialize stopwords and lemmatizer
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def clean_text(text, remove_stopwords=False):
    text = str(text).lower()                     # lowercase
    text = re.sub(r'\d+', '', text)             # remove numbers
    text = re.sub(r'[^\w\s]', '', text)         # remove punctuation
    text = text.strip()                          # remove leading/trailing spaces

    # Tokenize
    words = word_tokenize(text)

    # Lemmatize
    words = [lemmatizer.lemmatize(word) for word in words]

    if remove_stopwords:
        words = [word for word in words if word not in stop_words]

    return " ".join(words)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Laytong
# [nltk_data]     Ly\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Laytong
# [nltk_data]     Ly\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Laytong
# [nltk_data]     Ly\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Laytong
# [nltk_data]     Ly\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df["question_clean"] = df["question"].apply(lambda x: clean_text(x, remove_stopwords=True))

# %%
df
# Out:
#                         category  \
# 0              Academic Policies
# 1              Academic Policies
# 2              Academic Policies
# 3              Academic Policies
# 4              Academic Policies
# ..                           ...
# 465  Tuition Fees & Scholarships
# 466  Tuition Fees & Scholarships
# 467  Tuition Fees & Scholarships
# 468  Tuition Fees & Scholarships
# 469  Tuition Fees & Scholarships
#
#                                               question  \
# 0        When can I take a leave of absence from AUPP?
# 1                     Who approves a leave of absence?
# 2            Where do I get the Leave of Absence form?
# 3    How long can I be on leave before I lose my st...
# 4    Can I return after taking a leave of absence, ...
# ..                                                 ...
# 465            What is the TOEFL ITP exam fee at AUPP?
# 466                    What is the placement exam fee?
# 467          Where can students pay tuition on campus?
# 468           Can students pay tuition using ABA Bank?
# 469               Can students pay using Canadia Bank?
#
#                                                 answer  \
# 0    You can request a Leave of Absence (LOA) for l...
# 1    The authority to grant a Leave of Absence rest...
# 2    You can obtain the LOA Form from the Office of...
# 3    The specific duration of leave allowed is deta...
# 4    Yes, you can return after taking a leave of ab...
# ..                                                 ...
# 465                  The TOEFL ITP exam fee is USD 30.
# 466                   The placement exam costs USD 30.
# 467  Students can pay tuition directly at the AUPP ...
# 468  Yes. Tuition can be paid via ABA mobile app or...
# 469  Yes. Payments can be made through the Canadia ...
#
#                                          alt_questions  \
# 0    [How do I apply for a leave of absence?, Can I...
# 1    [Who decides if I can take a leave?, Which off...
# 2    [How can I get the LOA form?, Where do I pick ...
# 3    [What is the maximum time I can be on leave?, ...
# 4    [How do I come back after a LOA?, Can I rejoin...
# ..                                                 ...
# 465  [How much is the TOEFL ITP exam fee?, Does AUP...
# 466  [How much is the placement exam fee?, Does AUP...
# 467  [Where is tuition paid at AUPP?, Can tuition b...
# 468  [Can tuition be paid through ABA Bank?, Does A...
# 469  [Can tuition be paid through Canadia Bank?, Do...
#
#                                question_clean
# 0                     take leave absence aupp
# 1                      approves leave absence
# 2                      get leave absence form
# 3              long leave lose student status
# 4    return taking leave absence apply return
# ..                                        ...
# 465                   toefl itp exam fee aupp
# 466                        placement exam fee
# 467                student pay tuition campus
# 468        student pay tuition using aba bank
# 469            student pay using canadia bank
#
# [470 rows x 5 columns]

# %%
rows = []
for idx, row in df.iterrows():
    # main question
    rows.append({
        "question": row['question_clean'],
        "category": row['category'],
        "answer": row['answer']
    })
    # alternative questions
    for alt in row['alt_questions']:
        rows.append({
            "question": alt,
            "category": row['category'],
            "answer": row['answer']
        })

df_expanded = pd.DataFrame(rows)

# %%
df_expanded
# Out:
#                                              question  \
# 0                             take leave absence aupp
# 1              How do I apply for a leave of absence?
# 2                      Can I take time off from AUPP?
# 3            What are the rules for requesting a LOA?
# 4     When am I allowed to take a break from studies?
# ...                                               ...
# 2344                   student pay using canadia bank
# 2345        Can tuition be paid through Canadia Bank?
# 2346          Does AUPP accept Canadia Bank payments?
# 2347   Is Canadia Bank available for tuition payment?
# 2348     Can I use Canadia mobile app to pay tuition?
#
#                          category  \
# 0               Academic Policies
# 1               Academic Policies
# 2               Academic Policies
# 3               Academic Policies
# 4               Academic Policies
# ...                           ...
# 2344  Tuition Fees & Scholarships
# 2345  Tuition Fees & Scholarships
# 2346  Tuition Fees & Scholarships
# 2347  Tuition Fees & Scholarships
# 2348  Tuition Fees & Scholarships
#
#                                                  answer
# 0     You can request a Leave of Absence (LOA) for l...
# 1     You can request a Leave of Absence (LOA) for l...
# 2     You can request a Leave of Absence (LOA) for l...
# 3     You can request a Leave of Absence (LOA) for l...
# 4     You can request a Leave of Absence (LOA) for l...
# ...                                                 ...
# 2344  Yes. Payments can be made through the Canadia ...
# 2345  Yes. Payments can be made through the Canadia ...
# 2346  Yes. Payments can be made through the Canadia ...
# 2347  Yes. Payments can be made through the Canadia ...
# 2348  Yes. Payments can be made through the Canadia ...
#
# [2349 rows x 3 columns]

# %%
df_expanded["category"].value_counts()
# Out:
# category
# Academic Policies              720
# University Leadership          395
# Career/Faculty Info            345
# Programs & Majors              270
# Professional Programs          220
# Tuition Fees & Scholarships    202
# University Info                197
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Feature Selection and Data Splitting

# %%
X = df_expanded["question"]
y = df_expanded["category"]
answers = df_expanded["answer"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, ans_train, ans_test = train_test_split(X, y, answers, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1879,)
# (470,)
# (1879,)
# (470,)

# %% [markdown]
# ## 4. Train TF-IDF + Logistic Regression Classifier

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

pipeline_lr = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words="english", max_features=5000, ngram_range=(1, 2))),
    ('clf', LogisticRegression(max_iter=1000))
])

pipeline_lr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=5000, ngram_range=(1, 2),
#                                  stop_words='english')),
#                 ('clf', LogisticRegression(max_iter=1000))])

# %%
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_lr = pipeline_lr.predict(X_test)

cm = confusion_matrix(y_test, y_pred_lr)
sns.heatmap(cm, annot=True, cmap="Blues", fmt='d')

plt.title("Confusion Matrix for Logistic Regression")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

print(f"\nclassification report for Logistic Regression: \n\n{classification_report(y_test, y_pred_lr)}")
# Out:
# classification report for Logistic Regression:
#
#                              precision    recall  f1-score   support
#
#           Academic Policies       0.93      0.97      0.95       152
#         Career/Faculty Info       0.88      0.97      0.92        66
#       Professional Programs       1.00      0.93      0.96        41
#           Programs & Majors       1.00      0.80      0.89        45
# Tuition Fees & Scholarships       1.00      0.93      0.96        43
#             University Info       0.70      0.68      0.69        38
#       University Leadership       0.99      1.00      0.99        85
#
#                    accuracy                           0.93       470
#                   macro avg       0.93      0.90      0.91       470
#                weighted avg       0.93      0.93      0.93       470

# %% [markdown]
# ## 5. Train TF-IDF + Naive Bayes Classifier

# %%
from sklearn.naive_bayes import MultinomialNB

pipeline_nb = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words="english", max_features=5000,  ngram_range=(1, 2))),
     ('clf', MultinomialNB())
])

pipeline_nb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=5000, ngram_range=(1, 2),
#                                  stop_words='english')),
#                 ('clf', MultinomialNB())])

# %%
y_pred_nb = pipeline_nb.predict(X_test)

cm = confusion_matrix(y_test, y_pred_nb)
sns.heatmap(cm, annot=True, cmap="Greens", fmt='d')

plt.title("Confusion Matrix for Naive Bayes")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

print(f"\nclassification report for Naive Bayes: \n\n{classification_report(y_test, y_pred_nb)}")
# Out:
# classification report for Naive Bayes:
#
#                              precision    recall  f1-score   support
#
#           Academic Policies       0.84      0.99      0.91       152
#         Career/Faculty Info       0.84      0.98      0.91        66
#       Professional Programs       1.00      0.93      0.96        41
#           Programs & Majors       1.00      0.87      0.93        45
# Tuition Fees & Scholarships       1.00      0.86      0.93        43
#             University Info       0.93      0.37      0.53        38
#       University Leadership       0.99      1.00      0.99        85
#
#                    accuracy                           0.91       470
#                   macro avg       0.94      0.86      0.88       470
#                weighted avg       0.92      0.91      0.90       470

# %% [markdown]
# ## 6. Train TF-IDF + Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

pipeline_rf = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words="english", max_features=5000,  ngram_range=(1, 2))),
     ('clf', RandomForestClassifier())
])

pipeline_rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=5000, ngram_range=(1, 2),
#                                  stop_words='english')),
#                 ('clf', RandomForestClassifier())])

# %%
y_pred_rf = pipeline_rf.predict(X_test)

cm = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(cm, annot=True, cmap="Oranges", fmt='d')

plt.title("Confusion Matrix for Random Forest")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

print(f"\nclassification report for Random Forest: \n\n{classification_report(y_test, y_pred_rf)}")
# Out:
# classification report for Random Forest:
#
#                              precision    recall  f1-score   support
#
#           Academic Policies       0.92      0.95      0.94       152
#         Career/Faculty Info       0.84      0.98      0.91        66
#       Professional Programs       1.00      0.93      0.96        41
#           Programs & Majors       0.97      0.82      0.89        45
# Tuition Fees & Scholarships       1.00      0.91      0.95        43
#             University Info       0.68      0.74      0.71        38
#       University Leadership       0.97      0.91      0.94        85
#
#                    accuracy                           0.91       470
#                   macro avg       0.91      0.89      0.90       470
#                weighted avg       0.92      0.91      0.91       470

# %% [markdown]
# ## 7. Train TF-IDF + Support Vector Machine Classifier

# %%
from sklearn.svm import LinearSVC

pipeline_svm = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words="english", max_features=5000,  ngram_range=(1, 2))),
     ('clf', LinearSVC())
])

pipeline_svm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=5000, ngram_range=(1, 2),
#                                  stop_words='english')),
#                 ('clf', LinearSVC())])

# %%
y_pred_svm = pipeline_svm.predict(X_test)

cm = confusion_matrix(y_test, y_pred_svm)
sns.heatmap(cm, annot=True, cmap="Purples", fmt='d')

plt.title("Confusion Matrix for Support Vector Machine")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

print(f"\nclassification report for Support Vector Machine: \n\n{classification_report(y_test, y_pred_svm)}")
# Out:
# classification report for Support Vector Machine:
#
#                              precision    recall  f1-score   support
#
#           Academic Policies       0.98      0.97      0.97       152
#         Career/Faculty Info       0.87      0.98      0.92        66
#       Professional Programs       1.00      0.95      0.97        41
#           Programs & Majors       1.00      0.93      0.97        45
# Tuition Fees & Scholarships       1.00      0.95      0.98        43
#             University Info       0.81      0.79      0.80        38
#       University Leadership       0.99      1.00      0.99        85
#
#                    accuracy                           0.96       470
#                   macro avg       0.95      0.94      0.94       470
#                weighted avg       0.96      0.96      0.96       470

# %%
from sklearn.ensemble import GradientBoostingClassifier

pipeline_gb = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words="english", max_features=5000,  ngram_range=(1, 2))),
    ('clf', GradientBoostingClassifier())
])

pipeline_gb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=5000, ngram_range=(1, 2),
#                                  stop_words='english')),
#                 ('clf', GradientBoostingClassifier())])

# %%
y_pred_gb = pipeline_gb.predict(X_test)

cm = confusion_matrix(y_test, y_pred_gb)
sns.heatmap(cm, annot=True, cmap="Greys", fmt='d')

plt.title("Confusion Matrix for Gradient Boosting")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

print(f"\nclassification report for Gradient Boosting: \n\n{classification_report(y_test, y_pred_gb)}")
# Out:
# classification report for Gradient Boosting:
#
#                              precision    recall  f1-score   support
#
#           Academic Policies       0.86      0.93      0.89       152
#         Career/Faculty Info       0.89      0.98      0.94        66
#       Professional Programs       1.00      0.98      0.99        41
#           Programs & Majors       1.00      0.89      0.94        45
# Tuition Fees & Scholarships       0.98      0.93      0.95        43
#             University Info       0.78      0.84      0.81        38
#       University Leadership       0.96      0.80      0.87        85
#
#                    accuracy                           0.91       470
#                   macro avg       0.92      0.91      0.91       470
#                weighted avg       0.91      0.91      0.91       470

# %% [markdown]
# ## 7. Model Comparison

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

models = {
    "Logistic Regression": pipeline_lr,
    "Gradient Boosting": pipeline_gb,
    "Random Forest": pipeline_rf,
    "SVM": pipeline_svm,
    "Naive Bayes": pipeline_nb
}

results = []

for name, model in models.items():
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    macro_f1 = f1_score(y_test, y_pred, average='macro')
    precision = precision_score(y_test, y_pred, average='macro', zero_division=True)
    recall = recall_score(y_test, y_pred, average='macro')
    results.append(
        {"Model": name,
         "Accuracy": acc,
         "Macro F1": macro_f1,
         "Precision": precision,
         "Recall": recall
         })

df_results = pd.DataFrame(results)
df_results = df_results.sort_values(by="Macro F1", ascending=False)

# %%
df_results
# Out:
#                  Model  Accuracy  Macro F1  Precision    Recall
# 3                  SVM  0.955319  0.943765   0.949407  0.939924
# 1    Gradient Boosting  0.906383  0.912970   0.923430  0.907045
# 0  Logistic Regression  0.929787  0.910262   0.927541  0.897808
# 2        Random Forest  0.912766  0.899610   0.913310  0.891078
# 4          Naive Bayes  0.910638  0.879462   0.944080  0.856296

# %%
models = df_results["Model"]
accuracies = df_results["Accuracy"]

plt.figure(figsize=(8, 5))

colors = ["red", "blue", "green", "orange", "purple", "brown"]

plt.bar(models, accuracies, color=colors[:len(models)])

for i, acc in enumerate(accuracies):
    plt.text(i, acc + 0.01, f"{acc*100:.1f}%", ha="center")

plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## The SVM model performs the best among all models, achieving the highest accuracy at **95.5%**, indicating it is the most effective classifier in this comparison.

# %% [markdown]
# # 8. Save SVM Model

# %%
import joblib

joblib.dump(pipeline_svm, "pipeline_svm.joblib")
print("Model Saved Succesfully!")
# Out:
# Model Saved Succesfully!

# %% [markdown]
# ## 9. Generate SBERT Embeddings for Questions

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import joblib

sbert = SentenceTransformer("all-MiniLM-L6-v2")

df_expanded["embedding"] = df_expanded["question"].apply(lambda x: sbert.encode(x))

# %%
joblib.dump(df_expanded, "faq_with_embeddings.joblib")
print("SBERT FAQ Embeddings Saved Succesfully!")
# Out:
# SBERT FAQ Embeddings Saved Succesfully!

# %% [markdown]
# ## 10. Sample Testing ChatBot

# %%
import numpy as np
import joblib
from sentence_transformers import SentenceTransformer

# Load saved models
pipeline = joblib.load("pipeline_svm.joblib")          # Category classifier
df_faq = joblib.load("faq_with_embeddings.joblib") # FAQ with embeddings
sbert = SentenceTransformer("all-MiniLM-L6-v2")   # SBERT model

def get_answer(user_input):
    # Step 1: Predict category
    pred_category = pipeline.predict([user_input])[0]

    # Step 2: Filter FAQs by predicted category
    df_cat = df_faq[df_faq['category'] == pred_category]

    # Step 3: Encode user input
    query_emb = sbert.encode(user_input)

    # Step 4: Compute cosine similarity within the category
    embeddings = np.vstack(df_cat['embedding'].values)
    cosine_sim = embeddings @ query_emb / (np.linalg.norm(embeddings, axis=1) * np.linalg.norm(query_emb))

    # Step 5: Pick the most similar question
    idx = np.argmax(cosine_sim)
    faq_row = df_cat.iloc[idx]

    return faq_row['category'], faq_row['answer']

# Chat loop
print("Welcome to Hybrid AUPP FAQ Chatbot! Type 'exit' to quit.")

while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("Chatbot: Goodbye!")
        break

    category, answer = get_answer(user_input)
    print(f"Chatbot ({category}): {answer}\n")
# Out:
# Welcome to Hybrid AUPP FAQ Chatbot! Type 'exit' to quit.
# Chatbot (University Info): Excellence and comparative value make AUPP unique compared to other universities in Cambodia. It is the only university in Cambodia that provides American style education in a state-of-the-art campus with modern facilities. Dual Degree options with University of Arizona and Fort Hayes State University allow students to graduate with a U.S. degree at special tuition rates. The majority of AUPP faculty hold doctoral degrees and have international teaching experience. Our two-year general education curriculum is recognized globally, helping students transfer abroad or pursue postgraduate studies.
#
# Chatbot: Goodbye!
